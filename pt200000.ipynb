# %% [markdown]
# <a href="https://www.kaggle.com/code/denizherand/pt200000?scriptVersionId=194284704" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# GÖREV 1: Veri yapılarının tipleriniz inceleyiniz.

# %%
y = 3.2
type(3.2)
# Out:
# float
